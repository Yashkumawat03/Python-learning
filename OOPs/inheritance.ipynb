# %% [markdown]
# ## Inheritance

# %%
## Single Inheritance
## Parent class

class Car:
    def __init__(self,windows,doors,enginetype):
        self.windows = windows
        self.doors = doors
        self.enginetype = enginetype

    def drive(self):
        print(f"The person will drive the {self.enginetype} car.")

# %%
car1 = Car(4,5,"petrol")
car1.drive()
# Out:
# The person will drive the petrol car.

# %%
class Tesla(Car):
    def __init__(self,windows,doors,enginetype,is_selfdrive):
         super().__init__(windows,doors,enginetype)
         self.is_selfdrive=is_selfdrive

    def selfdriving(self):
        print(f"Tesla supports self deriving: {self.is_selfdrive}")

# %%
tesla1 = Tesla(4,5,"Petrol",True)
tesla1.selfdriving()
# Out:
# Tesla supports self deriving: True

# %%
### Multiple Inheritance
## When a class inherits from more than one class.
## Base class 1
class Animal:
    def __init__(self,name):
        self.name = name

    def speak(self):
        print("Subclss can implemen this method")

## Base class2

class Pet:
    def __init__(self,owner):
        self.owner = owner

## derived class 

class Dog(Animal,Pet):
    def __init__(self,name,owner):
        Animal.__init__(self,name)
        Pet.__init__(self,owner)

    def speak(self):
        return f"{self.name} say wolf"

## Create an object
dog = Dog("Buddy","Yash")
print(dog.speak())
print(dog.name)
# Out:
# Buddy say wolf
# Buddy
